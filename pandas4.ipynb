# %%
import pandas as pd
tit=pd.read_csv("DataSets-master/Titanic_Data.csv")

# %% [markdown]
# # set index and reset index

# %%
tit.set_index("Name",inplace=True)

# %%
tit.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
tit.reset_index(drop=False)
#drop param drops the name index so we put it as false
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# 5                                     Moran, Mr. James            6         0
# 6                              McCarthy, Mr. Timothy J            7         0
# 7                       Palsson, Master. Gosta Leonard            8         0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9         1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)           10         1
# 10                     Sandstrom, Miss. Marguerite Rut           11         1
# ...

# %% [markdown]
# #  loc[]

# %%
# access data through row 
tit.head(11)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# McCarthy, Mr. Timothy J                                       7         0
# Palsson, Master. Gosta Leonard                                8         0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
# Sandstrom, Miss. Marguerite Rut                              11         1
#
# ...

# %%
tit.loc["Heikkinen, Miss. Laina"]
# Out:
# PassengerId                   3
# Survived                      1
# Pclass                        3
# Sex                      female
# Age                          26
# SibSp                         0
# Parch                         0
# Ticket         STON/O2. 3101282
# Fare                      7.925
# Cabin                       NaN
# Embarked                      S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
tit.loc["Braund, Mr. Owen Harris":"McCarthy, Mr. Timothy J"]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# McCarthy, Mr. Timothy J                                       7         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# ...

# %%
tit.loc[["Braund, Mr. Owen Harris","McCarthy, Mr. Timothy J","yogesh"]]
# here yogesh name is not exist then it fill NAN in every col
# Out:
# /home/yogesh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                          PassengerId  Survived  Pclass   Sex   Age  SibSp  \
# Name
# Braund, Mr. Owen Harris          1.0       0.0     3.0  male  22.0    1.0
# McCarthy, Mr. Timothy J          7.0       0.0     1.0  male  54.0    0.0
# yogesh                           NaN       NaN     NaN   NaN   NaN    NaN
#
#                          Parch     Ticket     Fare Cabin Embarked
# Name
# Braund, Mr. Owen Harris    0.0  A/5 21171   7.2500   NaN        S
# McCarthy, Mr. Timothy J    0.0      17463  51.8625   E46        S
# ...

# %% [markdown]
# # iloc[]

# %%
# index location
tit.iloc[5]
# Out:
# PassengerId         6
# Survived            0
# Pclass              3
# Sex              male
# Age               NaN
# SibSp               0
# Parch               0
# Ticket         330877
# Fare           8.4583
# Cabin             NaN
# Embarked            Q
# Name: Moran, Mr. James, dtype: object

# %%
tit.iloc[:5]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
tit.iloc[:]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# McCarthy, Mr. Timothy J                                       7         0
# Palsson, Master. Gosta Leonard                                8         0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
# Sandstrom, Miss. Marguerite Rut                              11         1
# Bonnell, Miss. Elizabeth                                     12         1
# ...

# %%
tit.iloc[[1,5,6,9]]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Moran, Mr. James                                              6         0
# McCarthy, Mr. Timothy J                                       7         0
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
#
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Moran, Mr. James                                         3    male   NaN
# McCarthy, Mr. Timothy J                                  1    male  54.0
# Nasser, Mrs. Nicholas (Adele Achem)                      2  female  14.0
#
#                                                     SibSp  Parch    Ticket  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0  PC 17599
# ...

# %% [markdown]
# # catch all ix method

# %%
tit.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
tit.ix["Heikkinen, Miss. Laina"]
# Out:
# /home/yogesh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# PassengerId                   3
# Survived                      1
# Pclass                        3
# Sex                      female
# Age                          26
# SibSp                         0
# Parch                         0
# Ticket         STON/O2. 3101282
# Fare                      7.925
# Cabin                       NaN
# Embarked                      S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
tit.ix[["Heikkinen, Miss. Laina","Allen, Mr. William Henry"]]
# Out:
# /home/yogesh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                           PassengerId  Survived  Pclass     Sex   Age  SibSp  \
# Name
# Heikkinen, Miss. Laina              3         1       3  female  26.0      0
# Allen, Mr. William Henry            5         0       3    male  35.0      0
#
#                           Parch            Ticket   Fare Cabin Embarked
# Name
# Heikkinen, Miss. Laina        0  STON/O2. 3101282  7.925   NaN        S
# Allen, Mr. William Henry      0            373450  8.050   NaN        S

# %%
'''
-->loc gets rows (or columns) with particular labels from the index.
-->iloc gets rows (or columns) at particular positions in the index (so it only takes integers).
-->ix usually tries to behave like loc but falls back to behaving like iloc if a label is not present in the index.
-->It's important to note some subtleties that can make ix slightly tricky to use:

-->if the index is of integer type, ix will only use label-based indexing and not fall back to position-based indexing. If the label is not in the index, an error is raised.

-->if the index does not contain only integers, then given an integer, ix will immediately use position-based indexing rather than label-based indexing. If however ix is given another type (e.g. a string), it can use label-based indexing.
'''
# Out:
# "\n-->loc gets rows (or columns) with particular labels from the index.\n-->iloc gets rows (or columns) at particular positions in the index (so it only takes integers).\n-->ix usually tries to behave like loc but falls back to behaving like iloc if a label is not present in the index.\n-->It's important to note some subtleties that can make ix slightly tricky to use:\n\n-->if the index is of integer type, ix will only use label-based indexing and not fall back to position-based indexing. If the label is not in the index, an error is raised.\n\n-->if the index does not contain only integers, then given an integer, ix will immediately use position-based indexing rather than label-based indexing. If however ix is given another type (e.g. a string), it can use label-based indexing.\n"

# %%
tit.loc["Heikkinen, Miss. Laina","Sex"]
# Out:
# 'female'

# %%
tit.iloc[4:6,3:5]
# Out:
#                            Sex   Age
# Name
# Allen, Mr. William Henry  male  35.0
# Moran, Mr. James          male   NaN

# %% [markdown]
# # set new values for cell or row

# %%
tit.ix["Heikkinen, Miss. Laina"]
# Out:
# /home/yogesh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# PassengerId                   3
# Survived                      1
# Pclass                        3
# Sex                      female
# Age                          26
# SibSp                         0
# Parch                         0
# Ticket         STON/O2. 3101282
# Fare                      7.925
# Cabin                       NaN
# Embarked                      S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
tit.ix["Heikkinen, Miss. Laina","Age"]=45
# Out:
# /home/yogesh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
tit.ix["Heikkinen, Miss. Laina"] # here age is change
# Out:
# /home/yogesh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# PassengerId                   3
# Survived                      1
# Pclass                        3
# Sex                      female
# Age                          45
# SibSp                         0
# Parch                         0
# Ticket         STON/O2. 3101282
# Fare                      7.925
# Cabin                       NaN
# Embarked                      S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
tit.ix["Heikkinen, Miss. Laina",["Survived","Pclass","Sex"]]=[0,9000,'male']
# Out:
# /home/yogesh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
tit.ix["Heikkinen, Miss. Laina"]
# Out:
# /home/yogesh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# PassengerId                   3
# Survived                      0
# Pclass                     9000
# Sex                        male
# Age                          45
# SibSp                         0
# Parch                         0
# Ticket         STON/O2. 3101282
# Fare                      7.925
# Cabin                       NaN
# Embarked                      S
# Name: Heikkinen, Miss. Laina, dtype: object

# %% [markdown]
# # rename index name

# %%
tit.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                9000    male  45.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
tit.rename(columns={"Sex":"Gender"})
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# McCarthy, Mr. Timothy J                                       7         0
# Palsson, Master. Gosta Leonard                                8         0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
# Sandstrom, Miss. Marguerite Rut                              11         1
# Bonnell, Miss. Elizabeth                                     12         1
# ...

# %%
tit.rename(index={"Braund, Mr. Owen Harris":"yogesh sharma"})
# Out:
#                                                     PassengerId  Survived  \
# Name
# yogesh sharma                                                 1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# McCarthy, Mr. Timothy J                                       7         0
# Palsson, Master. Gosta Leonard                                8         0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
# Sandstrom, Miss. Marguerite Rut                              11         1
# Bonnell, Miss. Elizabeth                                     12         1
# ...

# %%
tit.columns=["id","alive","class","traveller Sex","traveller Age","Sibsp","Parch","Ticket","Fare","Cabin","Embarked"]

# %%
tit.head()
# Out:
#                                                     id  alive  class  \
# Name
# Braund, Mr. Owen Harris                              1      0      3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   2      1      1
# Heikkinen, Miss. Laina                               3      0   9000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         4      1      1
# Allen, Mr. William Henry                             5      0      3
#
#                                                    traveller Sex  \
# Name
# Braund, Mr. Owen Harris                                     male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...        female
# Heikkinen, Miss. Laina                                      male
# Futrelle, Mrs. Jacques Heath (Lily May Peel)              female
# Allen, Mr. William Henry                                    male
#
#                                                     traveller Age  Sibsp  \
# Name
# ...

# %% [markdown]
# # query method

# %%
# query method can apply if there is string values which are not seprated by space
tit.columns=[col.replace(" ","_") for col in tit.columns]

# %%
tit.head()
# Out:
#                                                     id  alive  class  \
# Name
# Braund, Mr. Owen Harris                              1      0      3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   2      1      1
# Heikkinen, Miss. Laina                               3      0   9000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         4      1      1
# Allen, Mr. William Henry                             5      0      3
#
#                                                    traveller_Sex  \
# Name
# Braund, Mr. Owen Harris                                     male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...        female
# Heikkinen, Miss. Laina                                      male
# Futrelle, Mrs. Jacques Heath (Lily May Peel)              female
# Allen, Mr. William Henry                                    male
#
#                                                     traveller_Age  Sibsp  \
# Name
# ...

# %%
tit.query('traveller_Sex=="male"')
# Out:
#                                           id  alive  class traveller_Sex  \
# Name
# Braund, Mr. Owen Harris                    1      0      3          male
# Heikkinen, Miss. Laina                     3      0   9000          male
# Allen, Mr. William Henry                   5      0      3          male
# Moran, Mr. James                           6      0      3          male
# McCarthy, Mr. Timothy J                    7      0      1          male
# Palsson, Master. Gosta Leonard             8      0      3          male
# Saundercock, Mr. William Henry            13      0      3          male
# Andersson, Mr. Anders Johan               14      0      3          male
# Rice, Master. Eugene                      17      0      3          male
# Williams, Mr. Charles Eugene              18      1      2          male
# Fynney, Mr. Joseph J                      21      0      2          male
# Beesley, Mr. Lawrence                     22      1      2          male
# ...

# %% [markdown]
# # delete row or col

# %%
tit.drop("Braund, Mr. Owen Harris")
# Out:
#                                                      id  alive  class  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...    2      1      1
# Heikkinen, Miss. Laina                                3      0   9000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)          4      1      1
# Allen, Mr. William Henry                              5      0      3
# Moran, Mr. James                                      6      0      3
# McCarthy, Mr. Timothy J                               7      0      1
# Palsson, Master. Gosta Leonard                        8      0      3
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     9      1      3
# Nasser, Mrs. Nicholas (Adele Achem)                  10      1      2
# Sandstrom, Miss. Marguerite Rut                      11      1      3
# Bonnell, Miss. Elizabeth                             12      1      1
# Saundercock, Mr. William Henry                       13      0      3
# ...

# %%
tit.drop(["Braund, Mr. Owen Harris","Heikkinen, Miss. Laina"])
# Out:
#                                                      id  alive  class  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...    2      1      1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)          4      1      1
# Allen, Mr. William Henry                              5      0      3
# Moran, Mr. James                                      6      0      3
# McCarthy, Mr. Timothy J                               7      0      1
# Palsson, Master. Gosta Leonard                        8      0      3
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     9      1      3
# Nasser, Mrs. Nicholas (Adele Achem)                  10      1      2
# Sandstrom, Miss. Marguerite Rut                      11      1      3
# Bonnell, Miss. Elizabeth                             12      1      1
# Saundercock, Mr. William Henry                       13      0      3
# Andersson, Mr. Anders Johan                          14      0      3
# ...

# %%
tit.drop("Parch",axis=1)
# axis =1 tells to drop column
# Out:
#                                                      id  alive  class  \
# Name
# Braund, Mr. Owen Harris                               1      0      3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...    2      1      1
# Heikkinen, Miss. Laina                                3      0   9000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)          4      1      1
# Allen, Mr. William Henry                              5      0      3
# Moran, Mr. James                                      6      0      3
# McCarthy, Mr. Timothy J                               7      0      1
# Palsson, Master. Gosta Leonard                        8      0      3
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     9      1      3
# Nasser, Mrs. Nicholas (Adele Achem)                  10      1      2
# Sandstrom, Miss. Marguerite Rut                      11      1      3
# Bonnell, Miss. Elizabeth                             12      1      1
# ...

# %%
tit.drop(["Cabin","class"],axis=1)
# Out:
#                                                      id  alive traveller_Sex  \
# Name
# Braund, Mr. Owen Harris                               1      0          male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...    2      1        female
# Heikkinen, Miss. Laina                                3      0          male
# Futrelle, Mrs. Jacques Heath (Lily May Peel)          4      1        female
# Allen, Mr. William Henry                              5      0          male
# Moran, Mr. James                                      6      0          male
# McCarthy, Mr. Timothy J                               7      0          male
# Palsson, Master. Gosta Leonard                        8      0          male
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     9      1        female
# Nasser, Mrs. Nicholas (Adele Achem)                  10      1        female
# Sandstrom, Miss. Marguerite Rut                      11      1        female
# ...

# %%
alive=tit.pop("alive")
tit.head()
# Out:
#                                                     id  class traveller_Sex  \
# Name
# Braund, Mr. Owen Harris                              1      3          male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   2      1        female
# Heikkinen, Miss. Laina                               3   9000          male
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         4      1        female
# Allen, Mr. William Henry                             5      3          male
#
#                                                     traveller_Age  Sibsp  \
# Name
# Braund, Mr. Owen Harris                                      22.0      1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...           38.0      1
# Heikkinen, Miss. Laina                                       45.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                 35.0      1
# Allen, Mr. William Henry                                     35.0      0
#
# ...

# %%
alive.head()
# Out:
# Name
# Braund, Mr. Owen Harris                                0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    1
# Heikkinen, Miss. Laina                                 0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           1
# Allen, Mr. William Henry                               0
# Name: alive, dtype: int64

# %%
del tit["Sibsp"]

# %%
tit.head()
# Out:
#                                                     id  class traveller_Sex  \
# Name
# Braund, Mr. Owen Harris                              1      3          male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   2      1        female
# Heikkinen, Miss. Laina                               3   9000          male
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         4      1        female
# Allen, Mr. William Henry                             5      3          male
#
#                                                     traveller_Age  Parch  \
# Name
# Braund, Mr. Owen Harris                                      22.0      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...           38.0      0
# Heikkinen, Miss. Laina                                       45.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                 35.0      0
# Allen, Mr. William Henry                                     35.0      0
#
# ...

# %% [markdown]
# # .Sample() method

# %%
tit.sample()
# show random result
# Out:
#                            id  class traveller_Sex  traveller_Age  Parch  \
# Name
# Thayer, Mr. John Borland  699      1          male           49.0      1
#
#                          Ticket      Fare Cabin Embarked
# Name
# Thayer, Mr. John Borland  17421  110.8833   C68        C

# %%
tit.sample(n=3)
# n def the number of random row
# Out:
#                                                 id  class traveller_Sex  \
# Name
# Carbines, Mr. William                          192      2          male
# Carter, Mrs. Ernest Courtenay (Lilian Hughes)  855      2        female
# Renouf, Mrs. Peter Henry (Lillian Jefferys)    727      2        female
#
#                                                traveller_Age  Parch  Ticket  \
# Name
# Carbines, Mr. William                                   19.0      0   28424
# Carter, Mrs. Ernest Courtenay (Lilian Hughes)           44.0      0  244252
# Renouf, Mrs. Peter Henry (Lillian Jefferys)             30.0      0   31027
#
#                                                Fare Cabin Embarked
# Name
# Carbines, Mr. William                          13.0   NaN        S
# Carter, Mrs. Ernest Courtenay (Lilian Hughes)  26.0   NaN        S
# Renouf, Mrs. Peter Henry (Lillian Jefferys)    21.0   NaN        S

# %%
tit.sample(frac=.01)
# Out:
#                                              id  class traveller_Sex  \
# Name
# Nasser, Mr. Nicholas                        123      2          male
# Sage, Mr. George John Jr                    325      3          male
# Chapman, Mr. John Henry                     595      2          male
# Landergren, Miss. Aurora Adelia             377      3        female
# Hansen, Mr. Henry Damsgaard                 624      3          male
# Mionoff, Mr. Stoytcho                       106      3          male
# Soholt, Mr. Peter Andreas Lauritz Andersen  716      3          male
# Perreault, Miss. Anne                       521      1        female
# Simmons, Mr. John                           564      3          male
#
#                                             traveller_Age  Parch  \
# Name
# Nasser, Mr. Nicholas                                 32.5      0
# Sage, Mr. George John Jr                              NaN      2
# Chapman, Mr. John Henry                              37.0      0
# ...

# %%
# col wise
tit.sample(n=3,axis=1)
# Out:
#                                                               Ticket  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599
# Heikkinen, Miss. Laina                              STON/O2. 3101282
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803
# Allen, Mr. William Henry                                      373450
# Moran, Mr. James                                              330877
# McCarthy, Mr. Timothy J                                        17463
# Palsson, Master. Gosta Leonard                                349909
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             347742
# Nasser, Mrs. Nicholas (Adele Achem)                           237736
# Sandstrom, Miss. Marguerite Rut                              PP 9549
# Bonnell, Miss. Elizabeth                                      113783
# ...

# %% [markdown]
# # nsmallest() and nlargest()

# %%
tit.nlargest(n=3,columns="traveller_Age")
# Out:
#                                        id  class traveller_Sex  traveller_Age  \
# Name
# Barkworth, Mr. Algernon Henry Wilson  631      1          male           80.0
# Svensson, Mr. Johan                   852      3          male           74.0
# Goldschmidt, Mr. George B              97      1          male           71.0
#
#                                       Parch    Ticket     Fare Cabin Embarked
# Name
# Barkworth, Mr. Algernon Henry Wilson      0     27042  30.0000   A23        S
# Svensson, Mr. Johan                       0    347060   7.7750   NaN        S
# Goldschmidt, Mr. George B                 0  PC 17754  34.6542    A5        C

# %%
tit.nsmallest(n=3,columns="traveller_Age")
# Out:
#                                   id  class traveller_Sex  traveller_Age  \
# Name
# Thomas, Master. Assad Alexander  804      3          male           0.42
# Hamalainen, Master. Viljo        756      2          male           0.67
# Baclini, Miss. Helene Barbara    470      3        female           0.75
#
#                                  Parch  Ticket     Fare Cabin Embarked
# Name
# Thomas, Master. Assad Alexander      1    2625   8.5167   NaN        C
# Hamalainen, Master. Viljo            1  250649  14.5000   NaN        S
# Baclini, Miss. Helene Barbara        1    2666  19.2583   NaN        C

# %%
tit["Fare"].nlargest(6)
# Out:
# Name
# Ward, Miss. Anna                      512.3292
# Cardeza, Mr. Thomas Drake Martinez    512.3292
# Lesurer, Mr. Gustave J                512.3292
# Fortune, Mr. Charles Alexander        263.0000
# Fortune, Miss. Mabel Helen            263.0000
# Fortune, Miss. Alice Elizabeth        263.0000
# Name: Fare, dtype: float64

# %% [markdown]
# # where() method

# %%
l1=tit["traveller_Sex"]=="male"
tit[l1].head()
# Out:
#                           id  class traveller_Sex  traveller_Age  Parch  \
# Name
# Braund, Mr. Owen Harris    1      3          male           22.0      0
# Heikkinen, Miss. Laina     3   9000          male           45.0      0
# Allen, Mr. William Henry   5      3          male           35.0      0
# Moran, Mr. James           6      3          male            NaN      0
# McCarthy, Mr. Timothy J    7      1          male           54.0      0
#
#                                     Ticket     Fare Cabin Embarked
# Name
# Braund, Mr. Owen Harris          A/5 21171   7.2500   NaN        S
# Heikkinen, Miss. Laina    STON/O2. 3101282   7.9250   NaN        S
# Allen, Mr. William Henry            373450   8.0500   NaN        S
# Moran, Mr. James                    330877   8.4583   NaN        Q
# McCarthy, Mr. Timothy J              17463  51.8625   E46        S

# %%
tit.where(l1).head()
# where method does not remove name it just fill NAN
# Out:
#                                                      id   class traveller_Sex  \
# Name
# Braund, Mr. Owen Harris                             1.0     3.0          male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  NaN     NaN           NaN
# Heikkinen, Miss. Laina                              3.0  9000.0          male
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        NaN     NaN           NaN
# Allen, Mr. William Henry                            5.0     3.0          male
#
#                                                     traveller_Age  Parch  \
# Name
# Braund, Mr. Owen Harris                                      22.0    0.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            NaN    NaN
# Heikkinen, Miss. Laina                                       45.0    0.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  NaN    NaN
# Allen, Mr. William Henry                                     35.0    0.0
#
# ...

# %%
tit.where(tit['Fare']>10).head()
# Out:
#                                                      id  class traveller_Sex  \
# Name
# Braund, Mr. Owen Harris                             NaN    NaN           NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  2.0    1.0        female
# Heikkinen, Miss. Laina                              NaN    NaN           NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        4.0    1.0        female
# Allen, Mr. William Henry                            NaN    NaN           NaN
#
#                                                     traveller_Age  Parch  \
# Name
# Braund, Mr. Owen Harris                                       NaN    NaN
# Cumings, Mrs. John Bradley (Florence Briggs Tha...           38.0    0.0
# Heikkinen, Miss. Laina                                        NaN    NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                 35.0    0.0
# Allen, Mr. William Henry                                      NaN    NaN
#
# ...

# %% [markdown]
# # apply() method

# %%
# it is used as broadcast method 
def add(num):
    return str(num)+" THOUSEND"

tit["Fare"]=tit["Fare"].apply(add)

# %%
tit.head()
# Out:
#                                                     id  class traveller_Sex  \
# Name
# Braund, Mr. Owen Harris                              1      3          male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   2      1        female
# Heikkinen, Miss. Laina                               3   9000          male
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         4      1        female
# Allen, Mr. William Henry                             5      3          male
#
#                                                     traveller_Age  Parch  \
# Name
# Braund, Mr. Owen Harris                                      22.0      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...           38.0      0
# Heikkinen, Miss. Laina                                       45.0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                 35.0      0
# Allen, Mr. William Henry                                     35.0      0
#
# ...

# %%
col=["id","Cabin",'class']
for c in col:
    tit[c]=tit[c].apply(add)

# %%
tit.head()
# Out:
#                                                             id          class  \
# Name
# Braund, Mr. Owen Harris                             1 THOUSEND     3 THOUSEND
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  2 THOUSEND     1 THOUSEND
# Heikkinen, Miss. Laina                              3 THOUSEND  9000 THOUSEND
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        4 THOUSEND     1 THOUSEND
# Allen, Mr. William Henry                            5 THOUSEND     3 THOUSEND
#
#                                                    traveller_Sex  \
# Name
# Braund, Mr. Owen Harris                                     male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...        female
# Heikkinen, Miss. Laina                                      male
# Futrelle, Mrs. Jacques Heath (Lily May Peel)              female
# Allen, Mr. William Henry                                    male
#
#                                                     traveller_Age  Parch  \
# Name
# ...
